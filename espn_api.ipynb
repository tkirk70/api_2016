# %% [markdown]
# # Newbees API - Draft Recap - 2016

# %%
# import requests

# api_key = 'your_api_key'
# league_id = 'your_league_id'

# url = f'https://fantasy.espn.com/apis/v3/games/ffl/seasons/2021/segments/0/leagues/{league_id}?view=kona_player_info'

# headers = {
#     'Content-Type': 'application/json',
#     'Authorization': f'Basic {api_key}'
# }

# response = requests.get(url, headers=headers)

# if response.status_code == 200:
#     players = response.json()['players']
#     print(players)
# else:
#     print(f'Error {response.status_code}: {response.reason}')

# %%
import requests
import pandas as pd

# %%
espn_cookies = {'swid': '{9B9225D3-7D25-467E-9DA5-B437D394DFEE}',
 'espn_s2': ''}

# %%
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36

# %%
url = 'https://fantasy.espn.com/apis/v3/games/ffl/leagueHistory/339188?view=mDraftDetail&view=mSettings&view=mTeam&view=modular&view=mNav&seasonId=2016'

# %%
headers = {
 'Connection': 'keep-alive',
 'Accept': 'application/json, text/plain, */*',
 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36',
}

# %%
r = requests.get(url, headers=headers, cookies=espn_cookies)
espn_raw_data = r.json()

# %%
espn_draft_detail = espn_raw_data[0]
draft_picks = espn_draft_detail['draftDetail']['picks']

# %%
df = pd.DataFrame(draft_picks)

# %%
df
# Out:
#      autoDraftTypeId  bidAmount   id  keeper  lineupSlotId  \
# 0                  0          0    1   False             0
# 1                  0          0    2   False             0
# 2                  0          0    3   False             4
# 3                  0          0    4   False             4
# 4                  0          0    5   False             4
# ..               ...        ...  ...     ...           ...
# 155                0          0  156   False            17
# 156                0          0  157   False            20
# 157                0          0  158   False            16
# 158                0          0  159   False            20
# 159                0          0  160   False            20
#
#                                  memberId  nominatingTeamId  \
# 0    3436600c-3252-4b39-a933-1f7beead9084                 0
# 1    3436600c-3252-4b39-a933-1f7beead9084                 0
# 2    3436600c-3252-4b39-a933-1f7beead9084                 0
# 3    3436600c-3252-4b39-a933-1f7beead9084                 0
# 4    3436600c-3252-4b39-a933-1f7beead9084                 0
# ..                                    ...               ...
# 155  3436600c-3252-4b39-a933-1f7beead9084                 0
# 156  3436600c-3252-4b39-a933-1f7beead9084                 0
# 157  3436600c-3252-4b39-a933-1f7beead9084                 0
# 158  3436600c-3252-4b39-a933-1f7beead9084                 0
# 159  3436600c-3252-4b39-a933-1f7beead9084                 0
#
#      overallPickNumber owningTeamIds  playerId  reservedForKeeper  roundId  \
# 0                    1           [2]     13994              False        1
# 1                    2           [6]      8439              False        1
# 2                    3          [13]     13934              False        1
# 3                    4           [3]     13982              False        1
# 4                    5           [5]     16733              False        1
# ..                 ...           ...       ...                ...      ...
# 155                156           [5]      4333              False       16
# 156                157           [3]     12601              False       16
# 157                158          [13]    -16017              False       16
# 158                159           [6]     14402              False       16
# 159                160           [2]      4527              False       16
#
#      roundPickNumber  teamId  tradeLocked
# 0                  1       2        False
# 1                  2       6        False
# 2                  3      13        False
# 3                  4       3        False
# 4                  5       5        False
# ..               ...     ...          ...
# 155                6       5        False
# 156                7       3        False
# 157                8      13        False
# 158                9       6        False
# 159               10       2        False
#
# [160 rows x 15 columns]

# %%
draft_df = df[['overallPickNumber', 'playerId', 'teamId']]

# %%
draft_df
# Out:
#      overallPickNumber  playerId  teamId
# 0                    1     13994       2
# 1                    2      8439       6
# 2                    3     13934      13
# 3                    4     13982       3
# 4                    5     16733       5
# ..                 ...       ...     ...
# 155                156      4333       5
# 156                157     12601       3
# 157                158    -16017      13
# 158                159     14402       6
# 159                160      4527       2
#
# [160 rows x 3 columns]

# %%
player_url = 'https://fantasy.espn.com/apis/v3/games/ffl/seasons/2016/players?scoringPeriodId=0&view=players_wl'

# %%
# x-fantasy-filter: {“filterActive”:null}
# x-fantasy-platform: kona-PROD-d8fba14d942cfef237ca6d6cc3ba9de27b91ae37
# x-fantasy-source: kona

# %%
headers = {
 'Connection': 'keep-alive',
 'Accept': 'application/json, text/plain, */*',
 'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
 'x-fantasy-filter': '{"filterActive":null}',
 'x-fantasy-platform': 'kona-PROD-1dc40132dc2070ef47881dc95b633e62cebc9913',
 'x-fantasy-source': 'kona'
}

# %%
r = requests.get(player_url, cookies=espn_cookies, headers=headers)
player_data = r.json()

# %%
df = pd.DataFrame(player_data)
# get only needed columns for players
player_df = df[['defaultPositionId','fullName','id','proTeamId']]
# rename id column for inner join
player_df.rename(columns = {'id':'player_id'}, inplace = True)
# Out:
# C:\Users\TechnologyDataServic\AppData\Local\Temp\ipykernel_22720\3134529855.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_df.rename(columns = {'id':'player_id'}, inplace = True)

# %%
player_df
# Out:
#       defaultPositionId         fullName  player_id  proTeamId
# 0                     2  Fozzy Whittaker      15755         29
# 1                     3    Jeremy Kelley      15758          3
# 2                     2   Austin Johnson      15765         27
# 3                    12        Tye Smith    2588098         10
# 4                     4     Darren Fells      15773          8
# ...                 ...              ...        ...        ...
# 5077                  3      Lance Lewis      15741         18
# 5078                 11     Jordan Hicks    2514270         21
# 5079                  9      Oren Wilson      15747          0
# 5080                  9    Bobby Skinner      15748          0
# 5081                  2       Jeff Demps      15749         11
#
# [5082 rows x 4 columns]

# %%
season_id = '2016'

url = "https://fantasy.espn.com/apis/v3/games/ffl/seasons/{}?view=proTeamSchedules_wl".format(season_id)
r = requests.get(url, cookies=espn_cookies)
team_data = r.json()
team_names = team_data['settings']['proTeams']
df = pd.DataFrame(team_names)
# get only needed columns for teams
team_df = df[['id', 'location', 'name']]
team_df["team name"] = team_df['location'].astype(str) +" "+ team_df["name"]
# rename in column
team_df.rename(columns = {'id':'team_id'}, inplace = True)
# Out:
# C:\Users\TechnologyDataServic\AppData\Local\Temp\ipykernel_22720\3923662058.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df["team name"] = team_df['location'].astype(str) +" "+ team_df["name"]
# C:\Users\TechnologyDataServic\AppData\Local\Temp\ipykernel_22720\3923662058.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df.rename(columns = {'id':'team_id'}, inplace = True)

# %%
team_df
# Out:
#     team_id       location        name             team name
# 0        11   Indianapolis       Colts    Indianapolis Colts
# 1        12    Kansas City      Chiefs    Kansas City Chiefs
# 2        13        Oakland     Raiders       Oakland Raiders
# 3        14    Los Angeles        Rams      Los Angeles Rams
# 4        15          Miami    Dolphins        Miami Dolphins
# 5        16      Minnesota     Vikings     Minnesota Vikings
# 6        17    New England    Patriots  New England Patriots
# 7        18    New Orleans      Saints    New Orleans Saints
# 8        19       New York      Giants       New York Giants
# 9        20       New York        Jets         New York Jets
# 10       21   Philadelphia      Eagles   Philadelphia Eagles
# 11       22        Arizona   Cardinals     Arizona Cardinals
# 12       23     Pittsburgh    Steelers   Pittsburgh Steelers
# 13       24      San Diego    Chargers    San Diego Chargers
# 14       25  San Francisco       49ers   San Francisco 49ers
# 15       26        Seattle    Seahawks      Seattle Seahawks
# 16       27      Tampa Bay  Buccaneers  Tampa Bay Buccaneers
# 17       28     Washington    Redskins   Washington Redskins
# 18       29       Carolina    Panthers     Carolina Panthers
# 19       30   Jacksonville     Jaguars  Jacksonville Jaguars
# 20       33      Baltimore      Ravens      Baltimore Ravens
# 21       34        Houston      Texans        Houston Texans
# 22        0                         FA                    FA
# 23        1        Atlanta     Falcons       Atlanta Falcons
# 24        2        Buffalo       Bills         Buffalo Bills
# 25        3        Chicago       Bears         Chicago Bears
# 26        4     Cincinnati     Bengals    Cincinnati Bengals
# 27        5      Cleveland      Browns      Cleveland Browns
# 28        6         Dallas     Cowboys        Dallas Cowboys
# 29        7         Denver     Broncos        Denver Broncos
# 30        8        Detroit       Lions         Detroit Lions
# 31        9      Green Bay     Packers     Green Bay Packers
# 32       10      Tennessee      Titans      Tennessee Titans

# %%
# merge tables together and save into a new df
df2 = pd.merge(draft_df, player_df, how="inner", left_on="playerId", right_on = "player_id")
# merge tables together and save into a new df
final_df = pd.merge(df2, team_df, how="inner", left_on="proTeamId", right_on = "team_id")

# %%
final_df
# Out:
#      overallPickNumber  playerId  teamId  defaultPositionId          fullName  \
# 0                    1     13994       2                  1        Cam Newton
# 1                   34     10475       1                  4        Greg Olsen
# 2                   42     11247       6                  2  Jonathan Stewart
# 3                   49     16730      12                  3   Kelvin Benjamin
# 4                  116    -16029       5                 16     Panthers D/ST
# ..                 ...       ...     ...                ...               ...
# 155                122   2978929       6                  3     Corey Coleman
# 156                137     17133       3                  2    Isaiah Crowell
# 157                 81     11788       2                  2    Danny Woodhead
# 158                127     15683       1                  5     Justin Tucker
# 159                157     12601       3                  3      Mike Wallace
#
#      player_id  proTeamId  team_id   location      name          team name
# 0        13994         29       29   Carolina  Panthers  Carolina Panthers
# 1        10475         29       29   Carolina  Panthers  Carolina Panthers
# 2        11247         29       29   Carolina  Panthers  Carolina Panthers
# 3        16730         29       29   Carolina  Panthers  Carolina Panthers
# 4       -16029         29       29   Carolina  Panthers  Carolina Panthers
# ..         ...        ...      ...        ...       ...                ...
# 155    2978929          5        5  Cleveland    Browns   Cleveland Browns
# 156      17133          5        5  Cleveland    Browns   Cleveland Browns
# 157      11788         33       33  Baltimore    Ravens   Baltimore Ravens
# 158      15683         33       33  Baltimore    Ravens   Baltimore Ravens
# 159      12601         33       33  Baltimore    Ravens   Baltimore Ravens
#
# [160 rows x 11 columns]

# %%
position_mapping = {
 1: 'QB',
 2: 'RB',
 3: 'WR',
 4: 'TE',
 5: 'K',
 16: 'D/ST'
}

# %%
# rename columns and map values for easier consumption. Save to new dataframe
league_draft = final_df.replace({"defaultPositionId": position_mapping})

# %%
league_draft
# Out:
#      overallPickNumber  playerId  teamId defaultPositionId          fullName  \
# 0                    1     13994       2                QB        Cam Newton
# 1                   34     10475       1                TE        Greg Olsen
# 2                   42     11247       6                RB  Jonathan Stewart
# 3                   49     16730      12                WR   Kelvin Benjamin
# 4                  116    -16029       5              D/ST     Panthers D/ST
# ..                 ...       ...     ...               ...               ...
# 155                122   2978929       6                WR     Corey Coleman
# 156                137     17133       3                RB    Isaiah Crowell
# 157                 81     11788       2                RB    Danny Woodhead
# 158                127     15683       1                 K     Justin Tucker
# 159                157     12601       3                WR      Mike Wallace
#
#      player_id  proTeamId  team_id   location      name          team name
# 0        13994         29       29   Carolina  Panthers  Carolina Panthers
# 1        10475         29       29   Carolina  Panthers  Carolina Panthers
# 2        11247         29       29   Carolina  Panthers  Carolina Panthers
# 3        16730         29       29   Carolina  Panthers  Carolina Panthers
# 4       -16029         29       29   Carolina  Panthers  Carolina Panthers
# ..         ...        ...      ...        ...       ...                ...
# 155    2978929          5        5  Cleveland    Browns   Cleveland Browns
# 156      17133          5        5  Cleveland    Browns   Cleveland Browns
# 157      11788         33       33  Baltimore    Ravens   Baltimore Ravens
# 158      15683         33       33  Baltimore    Ravens   Baltimore Ravens
# 159      12601         33       33  Baltimore    Ravens   Baltimore Ravens
#
# [160 rows x 11 columns]

# %%
newbees_teams = {
1: 'KIRK',
2: 'COLL',
3: 'CD',
5: 'CRIN',
6: 'SHIT',
11: 'SCHM',
12: 'HENE',
13: 'VU',
14: 'TKIRK',
16: 'MILL'
}

# %%
# rename columns and map values for easier consumption. Save to new dataframe
league_draft = league_draft.replace({"teamId": newbees_teams})

# %%
league_draft
# Out:
#      overallPickNumber  playerId teamId defaultPositionId          fullName  \
# 0                    1     13994   COLL                QB        Cam Newton
# 1                   34     10475   KIRK                TE        Greg Olsen
# 2                   42     11247   SHIT                RB  Jonathan Stewart
# 3                   49     16730   HENE                WR   Kelvin Benjamin
# 4                  116    -16029   CRIN              D/ST     Panthers D/ST
# ..                 ...       ...    ...               ...               ...
# 155                122   2978929   SHIT                WR     Corey Coleman
# 156                137     17133     CD                RB    Isaiah Crowell
# 157                 81     11788   COLL                RB    Danny Woodhead
# 158                127     15683   KIRK                 K     Justin Tucker
# 159                157     12601     CD                WR      Mike Wallace
#
#      player_id  proTeamId  team_id   location      name          team name
# 0        13994         29       29   Carolina  Panthers  Carolina Panthers
# 1        10475         29       29   Carolina  Panthers  Carolina Panthers
# 2        11247         29       29   Carolina  Panthers  Carolina Panthers
# 3        16730         29       29   Carolina  Panthers  Carolina Panthers
# 4       -16029         29       29   Carolina  Panthers  Carolina Panthers
# ..         ...        ...      ...        ...       ...                ...
# 155    2978929          5        5  Cleveland    Browns   Cleveland Browns
# 156      17133          5        5  Cleveland    Browns   Cleveland Browns
# 157      11788         33       33  Baltimore    Ravens   Baltimore Ravens
# 158      15683         33       33  Baltimore    Ravens   Baltimore Ravens
# 159      12601         33       33  Baltimore    Ravens   Baltimore Ravens
#
# [160 rows x 11 columns]

# %%
for item in espn_draft_detail['members']:
    print(item)
# Out:
# {'displayName': 'cuonga', 'firstName': 'Cuong', 'id': '{0654860E-F9F8-11D3-820C-00A0C9E58E2D}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'Vu'}
# {'displayName': 'Pat Patriot54', 'firstName': 'Jess', 'id': '{18D352BB-349D-4928-8025-99297946EB2C}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'Collier'}
# {'displayName': 'Mark405100', 'firstName': 'Mark', 'id': '{5259BD1C-8123-47BA-9EFA-F7C313EB5203}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'Foltz'}
# {'displayName': 'dlugolinski13', 'firstName': 'chris', 'id': '{5F0A4D57-E1EB-4162-A39A-C0EED17FABF3}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'dlugolinski'}
# {'displayName': 'samthelion44', 'firstName': 'jeff', 'id': '{8CEB3D56-5C06-4697-8A37-FB34216EF437}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'miller'}
# {'displayName': 'Timothy-Kirk', 'firstName': 'Timothy', 'id': '{9B9225D3-7D25-467E-9DA5-B437D394DFEE}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'Kirk'}
# {'displayName': 'busketneck1', 'firstName': 'craig', 'id': '{BFD238EA-3CB8-4C66-934B-DF61CB2BD66F}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'rinaldo'}
# {'displayName': 'Hendigidy1327', 'firstName': 'Frank', 'id': '{C1D34E02-0E94-4BEF-BA38-FF2BA16051B1}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'Henegar'}
# {'displayName': 'schmerr13', 'firstName': 'scott', 'id': '{EF99C28F-C386-49E9-A358-EBB70C462072}', 'isLeagueCreator': False, 'isLeagueManager': False, 'lastName': 'schmerr'}
# {'displayName': 'ryanlawrencekirk', 'firstName': 'Ryan', 'id': '{F9C308E1-95B7-4F5A-AB25-18B2CC73BE68}', 'isLeagueCreator': True, 'isLeagueManager': False, 'lastName': 'Kirk'}

# %%
for item in espn_draft_detail:
    print(item)
# Out:
# draftDetail
# gameId
# id
# members
# scoringPeriodId
# seasonId
# segmentId
# settings
# status
# teams

# %%
for item in espn_draft_detail['teams']:
    print(item['id'], item['abbrev'])
# Out:
# 1 KIRK
# 2 COLL
# 3 CD
# 5 CRIN
# 6 SHIT
# 11 SCHM
# 12 HENE
# 13 VU
# 14 KIRK
# 16 MILL

# %%
print(espn_draft_detail['scoringPeriodId'])
